# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# %%
data = gpd.read_file(r'data_raw/shape/ufb_rev_wald_teil.shp', encoding='utf-8')

# %%
data.head(53)
# Out:
#                           KREIS_NAME       REVUFB_NM REVUFBADR   NSW_FI  \
# 0                      Mittelsachsen       Reinsberg      2203  1597.32
# 1                      Mittelsachsen    Geringswalde      2201   841.61
# 2                            Leipzig  Leipziger Land      2902   401.71
# 3                      Mittelsachsen     Striegistal      2202   954.18
# 4                             Meißen             Süd      2703   392.75
# 5                        Nordsachsen         Oschatz      3003   271.09
# 6                        Nordsachsen       Delitzsch      3001    11.28
# 7                    Erzgebirgskreis      Eibenstock      2101   929.71
# 8                      Vogtlandkreis      Weischlitz      2303  2123.89
# 9                            Zwickau            Nord      2401  1319.45
# 10  Sächsische Schweiz-Osterzgebirge         Freital      2801  1675.64
# 11                   Erzgebirgskreis       Stollberg      2103  2903.46
# 12         Kreisfreie Stadt Chemnitz        Chemnitz      1101   280.84
# 13                   Erzgebirgskreis        Zschopau      2104  1745.57
# 14                            Meißen            West      2704    36.08
# 15                       Nordsachsen          Torgau      3002    14.46
# 16  Sächsische Schweiz-Osterzgebirge       Glashütte      2802  1439.74
# 17                   Erzgebirgskreis       Olbernhau      2107  1379.08
# 18          Kreisfreie Stadt Dresden         Dresden      1201   124.17
# 19                           Görlitz          Zittau      2601  3757.67
# 20                           Bautzen       Cunewalde      2510  3323.88
# 21                   Erzgebirgskreis      Marienberg      2106  2062.88
# 22                           Bautzen     Elsterheide      2501    11.37
# 23                     Vogtlandkreis        Schöneck      2302  2342.52
# 24                     Vogtlandkreis        Auerbach      2306  2748.21
# 25                     Vogtlandkreis          Plauen      2304  2152.93
# 26                     Vogtlandkreis          Treuen      2305  2621.37
# 27                           Zwickau             Süd      2402  1794.78
# 28                   Erzgebirgskreis         Zwönitz      2102  2953.21
# 29                   Erzgebirgskreis        Annaberg      2105  1855.40
# 30                     Vogtlandkreis           Adorf      2301  3922.55
# 31                            Meißen             Ost      2702   114.56
# 32                           Bautzen           Ohorn      2508  1028.08
# 33                           Bautzen   Bischofswerda      2509  2184.61
# 34                           Bautzen     Königsbrück      2505   173.07
# 35  Sächsische Schweiz-Osterzgebirge           Pirna      2804  1153.30
# 36                            Meißen            Nord      2701    33.41
# 37                           Bautzen         Radibor      2506   246.66
# 38  Sächsische Schweiz-Osterzgebirge         Sebnitz      2805  2152.83
# 39                           Bautzen          Kamenz      2507   721.84
# 40                           Görlitz     Krauschwitz      2604   401.00
# 41                           Görlitz         Boxberg      2605   146.13
# 42                           Görlitz           Löbau      2602  2858.26
# 43  Sächsische Schweiz-Osterzgebirge   Bad-Gottleuba      2803  1073.94
# 44                           Görlitz      Weißwasser      2606   103.70
# 45                           Leipzig       Muldental      2901   225.27
# 46                           Görlitz          Niesky      2603   631.21
# 47                           Bautzen       Bernsdorf      2502    60.79
# 48          Kreisfreie Stadt Leipzig       Connewitz      1302     0.54
# 49          Kreisfreie Stadt Leipzig        Leutzsch      1301     0.00
# 50                           Bautzen    Königswartha      2503   109.44
# 51                           Bautzen     Nebelschütz      2504   231.78
# 14  MULTIPOLYGON (((378097.915 5695126.311, 378079...
# 15  POLYGON ((373565.663 5697229.308, 373563.916 5...
# 16  POLYGON ((401257.526 5625647.704, 401276.133 5...
# 17  POLYGON ((389192.117 5614910.287, 389216.179 5...
# 18  POLYGON ((406287.660 5660744.821, 406292.672 5...
# 19  POLYGON ((487256.906 5634093.001, 487250.347 5...
# 20  MULTIPOLYGON (((464294.297 5672424.558, 464271...
# 21  MULTIPOLYGON (((373670.633 5615129.235, 373650...
# 22  POLYGON ((461891.849 5709682.380, 461896.773 5...
# 23  POLYGON ((321988.434 5593505.760, 322012.681 5...
# 24  MULTIPOLYGON (((303115.687 5590552.226, 303118...
# 25  POLYGON ((287866.262 5612777.466, 287905.092 5...
# 26  POLYGON ((310413.706 5617039.496, 310414.839 5...
# 27  POLYGON ((324855.422 5602320.960, 324853.742 5...
# 28  POLYGON ((339734.297 5598370.233, 339750.251 5...
# 29  MULTIPOLYGON (((347047.520 5608748.225, 347040...
# 30  POLYGON ((303454.420 5570168.592, 303489.054 5...
# 31  POLYGON ((413698.678 5674573.351, 413686.981 5...
# 32  POLYGON ((436847.811 5658282.168, 436846.160 5...
# 33  POLYGON ((450014.101 5658219.354, 449993.699 5...
# 34  POLYGON ((416928.162 5667771.869, 416921.844 5...
# 35  POLYGON ((451893.733 5656216.289, 451868.986 5...
# 36  POLYGON ((408736.142 5692125.831, 408767.450 5...
# 37  POLYGON ((467556.962 5687721.179, 467598.241 5...
# 38  POLYGON ((439933.822 5653028.493, 439937.778 5...
# 39  POLYGON ((426102.343 5679663.406, 426140.719 5...
# 40  POLYGON ((476212.043 5686748.226, 476191.848 5...
# 41  POLYGON ((471936.909 5703029.441, 472073.270 5...
# 42  POLYGON ((478041.240 5673382.418, 478102.396 5...
# 43  POLYGON ((422180.594 5626994.022, 422174.688 5...
# 44  POLYGON ((479760.427 5716282.141, 479861.148 5...
# 45  MULTIPOLYGON (((344749.444 5674375.053, 344776...
# 46  POLYGON ((487620.933 5691807.728, 487600.342 5...
# 47  MULTIPOLYGON (((436399.070 5701934.906, 436327...
# 48  POLYGON ((309068.910 5686587.644, 309075.504 5...
# 49  POLYGON ((326755.445 5691360.072, 326755.264 5...
# 50  POLYGON ((456788.179 5700262.099, 456817.163 5...
# 51  MULTIPOLYGON (((452465.754 5694302.012, 452449...
# 52  POLYGON ((387897.385 5645310.383, 387917.316 5...

# %%
kreis_data = data.dissolve(by='KREIS_NAME')
kreis_data.reset_index(inplace=True)

# %%
for dataset in [data, kreis_data]:
    dataset['coords'] = dataset['geometry'].apply(lambda x: x.representative_point().coords[:])
    dataset['coords'] = [coords[0] for coords in dataset['coords']]

# %%
fig, ax = plt.subplots(figsize=(30,30))
kreis_data.plot(ax=ax, legend=True, color='white',
                edgecolor='black', linewidth=1)
for idx, row in kreis_data.iterrows():
    ax.text(row.coords[0], row.coords[1], fontsize=20,
            s=row['KREIS_NAME'], horizontalalignment='center', 
            bbox={'facecolor': 'white', 'alpha':0.8, 'pad': 2, 'edgecolor':'none'})
    
plt.axis('off');

# %%
fig, ax = plt.subplots(figsize=(30,30))
data.plot(ax=ax, column='KREIS_NAME', legend=True,
          edgecolor='black', linewidth=1,
          cmap='terrain', legend_kwds={'fontsize': 20, 'loc': 'lower right'})

for idx, row in data.iterrows():
    ax.text(row.coords[0], row.coords[1], color='white', weight = 'bold', fontsize=20,
            s=row['REVUFB_NM'], horizontalalignment='center', 
            bbox={'facecolor': 'black', 'alpha':0.4, 'pad': 2, 'edgecolor':'none'})
    

plt.axis('off');

# %%
fig, ax = plt.subplots(figsize=(30,30))
data.plot(ax=ax, legend=True, color='white',
                edgecolor='black', linewidth=0.5)

kreis_data.plot(ax=ax, legend=True, color='none',
                edgecolor='black', linewidth=2)

width = 3000
colors = ['darkgreen', 'darkblue', 'lightgreen', 'lightblue']

for idx, row in data.iterrows():
    sw_fi = patches.Rectangle((row['coords'][0]-width/2, 
                                row['coords'][1]), 
                             width=width, height=row['SW_FI'], 
                              color=colors[0], ec='black'
                             )
    
    nsw_fi = patches.Rectangle((row['coords'][0]-width/2, 
                                   row['coords'][1] + row['SW_FI']), 
                             width=width, height=row['NSW_FI'], 
                               color=colors[1], ec='black'
                              )
    
    sw_sonst = patches.Rectangle((row['coords'][0]-width/2, 
                                   row['coords'][1] + row['SW_FI'] + row['NSW_FI']), 
                             width=width, height=row['SW_SONST'], 
                                 color=colors[2], ec='black'
                                )
    
    nsw_sonst = patches.Rectangle((row['coords'][0]-width/2, 
                                   row['coords'][1] + row['SW_FI'] + row['NSW_FI'] + row['SW_SONST']), 
                             width=width, height=row['NSW_SONST'], 
                                  color=colors[3], ec='black'
                                 )
    
    ax.add_patch(sw_fi)
    ax.add_patch(nsw_fi)
    ax.add_patch(sw_sonst)
    ax.add_patch(nsw_sonst)
    
    
plt.legend(handles=[patches.Patch(color=colors[3], label='Nichtstaatswald Sonstiges', ec='black'),
                    patches.Patch(color=colors[2], label='Staatswald Sonstiges', ec='black'),
                    patches.Patch(color=colors[1], label='Nichtstaatswald Fichte', ec='black'),
                    patches.Patch(color=colors[0], label='Staatswald Fichte', ec='black')],
          fontsize=26, loc='lower right')
plt.axis('off');
# Out:
# (267100.4013500002, 514160.39804999967, 5552730.938154999, 5736554.970745001)

# %%
data_old = gpd.read_file(r'data_raw/shape/ufb_rev_vorUmstrukturierungen.shp', encoding='utf-8')

# %%
data_old['coords'] = data_old['geometry'].apply(lambda x: x.representative_point().coords[:])
data_old['coords'] = [coords[0] for coords in data_old['coords']]

fig, ax = plt.subplots(figsize=(30,30))
data_old.plot(ax=ax, column='KREIS_NAME', legend=True,
          edgecolor='black', linewidth=1, 
          cmap='terrain', legend_kwds={'fontsize': 20, 'loc': 'lower right'})

for idx, row in data_old.iterrows():
    ax.text(row.coords[0], row.coords[1], color='white', weight = 'bold', fontsize=20,
            s=row['REVUFB_NM'], horizontalalignment='center', 
            bbox={'facecolor': 'black', 'alpha':0.4, 'pad': 2, 'edgecolor':'none'})
    

plt.axis('off');

# %%
fig, ax = plt.subplots(figsize=(30,30))
kreis_data.plot(ax=ax, legend=True, color='white',
                edgecolor='black', linewidth=2)
data_old.plot(ax=ax, legend=True, color='white',
                edgecolor='red', linewidth=1)

plt.axis('off');

# %%
data.crs
# Out:
# {'init': 'epsg:25833'}

# %%
import rasterio # the GEOS-based raster package
import rasterio.plot
import rasterstats
raster = rasterio.open(r'data_raw/climate_33_months_1000/GRID_1_Messungen_Tageswerte_2020_KWU_MW_20181200_utm.asc', nodata=-9999.0)

# %%
fig, ax = plt.subplots(figsize=(10, 15))
rasterio.plot.show(raster, cmap='hot', ax=ax)
ax.axis('off');

# %%
fig, ax = plt.subplots(figsize=(30,30))
rasterio.plot.show(raster, ax=ax)
data.plot(ax=ax, facecolor='none', edgecolor='red')
ax.axis('off');

# %%
adorf = data.iloc[30]

# %%
adorf = data[data['REVUFB_NM'] == 'Adorf']

bbox = adorf.total_bounds
window = raster.window(*bbox)
raster_adorf = raster.read(1, window=window)
raster_adorf
# Out:
# array([[   65.7,    62.7,    64.7,    68.5,    70.9,    71.5,    72. ,
#            76.6,    83.7,    79.4,    88.3,    87.5,    94. ,   108.7,
#           119.2,   121.3,   139.2,   146.5,   154.8,   164.2,   170. ,
#           168.7,   171.4,   174.1],
#        [   70.6,    75.4,    75.3,    67.4,    65.7,    69.6,    78.6,
#            80.3,    77.8,    80. ,    85.3,    86.4,    97. ,   105. ,
#           114.2,   121.8,   146.6,   155.4,   168.1,   178.5,   178.5,
#           178.6,   184.7,   188. ],
#        [   69.5,    75.5,    77.5,    76.2,    76.5,    71.5,    71.9,
#            69.9,    79.6,    82.9,    91.3,    85.1,    93. ,    97.9,
#           111.8,   127.9,   149.1,   163.3,   178.7,   183.3,   186.2,
#           187. ,   192. ,   194.3],
#        [   71.3,    72.3,    82.8,    82. ,    80.9,    77. ,    70.3,
#            74.1,    80.8,    88.2,    96.8,    96.2,   100.1,   110.1,
#           123.2,   138.2,   149.3,   168.9,   177.4,   182.1,   184.5,
#           190.4,   188.2,   190.7],
#        [   80.9,    71.5,    77.1,    82. ,    81.7,    74.6,    69.7,
#            82.5,    91.1,    92.1,   100.3,   102.7,   107.9,   109.5,
#           117.9,   130.9,   152.8,   167.5,   175.1,   180.8,   185.7,
#           186.8,   190. ,   180.3],
#        [   79.1,    74.1,    85.1,    88.7,    84.6,    80.2,    77.6,
#            71.1,    83.4,    86.8,    92.8,    97.7,   103.3,   109.2,
#           119.6,   130.7,   142.1,   162.2,   172. ,   180.8,   185.1,
#           181.6,   185.2,   176.4],
#        [   84.9,    75.7,    82.3,    88. ,    83.3,    78.4,    80.6,
#            74.3,    72.1,    88.7,    92.8,    90.8,    97.2,   108.6,
#           114.8,   121.3,   146.1,   160. ,   161.4,   171.4,   175.7,
#           172.5,   171.6,   172.3],
#        [   92.5,    81.9,    87.1,    85.1,    89.1,    86.4,    92.5,
#            88.6,    77.1,    86.7,    94.9,   106.8,   110.3,   114.1,
#           117.4,   124.7,   136.9,   154.2,   157.8,   162.7,   169.3,
#           165.1,   151. ,   159. ],
#        [   96.4,    87.9,    85.2,    86.7,    94.4,    86.3,    80.7,
9999. , -9999. , -9999. , -9999. ,
#         -9999. , -9999. , -9999. , -9999. , -9999. ,   115.6,   105. ,
#            99.1,    98.2,    99.5, -9999. , -9999. , -9999. , -9999. ,
#         -9999. , -9999. , -9999. ]], dtype=float32)

# %%
# nur einen Ausschnitt plotten
bbox = adorf.total_bounds

fig, ax = plt.subplots(figsize=(10,15))
rasterio.plot.show(raster, ax=ax)
adorf.plot(ax=ax, facecolor='none', edgecolor='red')

ax.set_xlim([bbox[0],  bbox[2]])
ax.set_ylim([bbox[1],  bbox[3]])

ax.axis('off');

# %% [markdown]
# ## Zonal stats
# How do we want to calculate zonal stats? Comparison of rasterstats.zonal_stats and a rasterio mask.

# %%
rasterband = raster.read(1)
transform = raster.transform
rasterstats.zonal_stats(adorf, rasterband, affine=transform, nodata=-9999.0, stats='mean')
# Out:
# [{'mean': 106.56679836469206}]

# %% [markdown]
# #### underfilled mask

# %%
from rasterio.mask import mask
masked, mask_transform = mask(dataset=raster, shapes=adorf.geometry, 
                              crop=True, # avoid loading in the whole raster
                              filled=False) # mask outside values with nodata, so we can safely compute our own stats

# %%
# remove one dimension from masked
print('initial shape: {}'.format(masked.shape)) # we only need the (7,6) array
masked = masked.squeeze()
print('final shape: {}'.format(masked.shape))
# Out:
# initial shape: (1, 31, 26)
# final shape: (31, 26)

# %%
plt.imshow(masked.squeeze(), extent=adorf.total_bounds[[0,2,1,3]])
adorf.boundary.plot(ax=plt.gca(), color='red', linewidth=2)
plt.axis('off');

# %%
masked.mean()
# Out:
# 106.56679996294466

# %%
np.ma.mean(masked)
# Out:
# 106.56679996294466

# %% [markdown]
# #### overfilled mask

# %%
masked, mask_transform = mask(dataset=raster, shapes=adorf.geometry, 
                              crop=True, # avoid loading in the whole raster
                              filled=False, # mask outside values with nodata, so we can safely compute our own stats
                              all_touched=True) # overfill instead of underfill
masked.mean()
# Out:
# 106.65474189082279

# %%
plt.imshow(masked.squeeze(), extent=adorf.total_bounds[[0,2,1,3]])
adorf.boundary.plot(ax=plt.gca(), color='red', linewidth=2)
plt.axis('off');

# %%
masked.mean()
# Out:
# 106.65474189082279

# %%
np.ma.median(masked)
# Out:
# 103.30000305175781

# %% [markdown]
# It seems that zonal_stats uses the underfilled mask by default to calculate the zonal statistics.

# %% [markdown]
# ## Mass Zonal stats

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
# apply the mask and zonal stats for every forestry district, then plot the result

# define masking process
def clean_mask(geom, dataset=raster, **mask_kw):
    mask_kw.setdefault('crop', True) # only load in the raster data local to the geom 
    mask_kw.setdefault('all_touched', True) # overfill=True, underfill=False
    mask_kw.setdefault('filled', False) # mask outside values with nodata to allow computing of stats
    masked, mask_transform = mask(dataset=dataset, shapes=(geom,),
                                  **mask_kw)
    return masked

# apply this mask for every forestry district

data['mean_temp'] = data.geometry.apply(clean_mask).apply(np.mean)

# plot
fig, ax = plt.subplots(figsize=(30,30))
plt.title('Mittlere Tagestemperatur am 15.03.2005', fontdict={'fontsize': 30})
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="2%", pad=0.1)
data.plot(ax=ax, column='mean_temp', edgecolor='black', 
          legend=True, 
          cax=cax)
plt.title('Temperatur \n in °C', fontdict={'fontsize': 20})
cax.tick_params(labelsize=20)
ax.axis('off');
